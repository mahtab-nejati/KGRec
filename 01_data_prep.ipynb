# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Prep Golden Mapping

# %%
def remove_empty(x):
    result = sorted(list(set(x)))
    try:
        result.remove('')
    except:
        pass
    return result

golden = pd.read_csv('./2020_repologue_data/golden_set_v3.csv')

golden['alias'] = golden['alias'].replace(np.nan, '', regex=True)
golden['alias'] = golden['alias'].apply(lambda x: x+',')
golden['our_sub_topics'] = golden['our_sub_topics'].replace(np.nan, '', regex=True)

golden['free'] = golden['alias']+golden['our_sub_topics']
golden = golden[golden.free != ","]
golden['free'] = golden['free'].replace(np.nan, '', regex=True)
golden['free'] = golden['free'].apply(lambda x: x.split(','))
golden['free'] = golden['free'].apply(lambda x: sorted(list(set(x))))
golden['free'] = golden['free'].apply(lambda x: remove_empty(x))
golden['free_str'] = golden['free'].apply(lambda x: ','.join(x))

golden.rename(columns={'Topics':'topic'}, inplace=True)
golden.drop(['alias','our_sub_topics'], axis=1, inplace=True)

frees = sorted(list(set([x for row in list(golden.free) for x in row])))

# %% [markdown]
# # Prep Mapped Data

# %%
df = pd.read_csv('./2020_repologue_data/repos_152k_top228_topics_compressed_2.csv')

df['featured_topics'] = df['featured_topics'].replace(np.nan, '', regex=True)

df['original_topics'] = df['original_topics'].apply(lambda x: x.split(','))
df['featured_topics'] = df['featured_topics'].apply(lambda x: x.split(','))
df['augmented_top228topics'] = df['augmented_top228topics'].apply(lambda x: x.split(','))

df['featured_topics'] = df['featured_topics'].apply(lambda x: [] if x==[""] else x)

original_topics = sorted(list(set([x for row in list(df.original_topics) for x in row])))
featured_topics = sorted(list(set([x for row in list(df.featured_topics) for x in row])))
augmented_top228topics = sorted(list(set([x for row in list(df.augmented_top228topics) for x in row])))

# Map originals based on the Golden Mapping

def get_full_mapping(x,frees=frees,golden=golden):
    result = []
    for item in x:
        if item in frees:
            result.append(golden[golden['free_str'].str.contains(item)]['topic'].values[0])
    return result

df.insert(4,'mapped_topics', df['original_topics'].apply(get_full_mapping))

df['mapped_topics'] = df['featured_topics']+df['augmented_top228topics']+df['mapped_topics']
df['mapped_topics'] = df['mapped_topics'].apply(lambda x: sorted(list(set(x))))

mapped_topics = sorted(list(set([x for row in list(df.mapped_topics) for x in row])))

# Reports

df.insert(6, 'len_original_topics', df['original_topics'].apply(lambda x : len(x)))
df.insert(7, 'len_featured_topics', df['featured_topics'].apply(lambda x : len(x)))
df.insert(8, 'len_augmented_top228topics', df['augmented_top228topics'].apply(lambda x : len(x)))
df.insert(9, 'len_mapped_topics', df['mapped_topics'].apply(lambda x : len(x)))

print('Topic Count')
print(f"original_topics\t\t{len(original_topics)}\nfeatured_topics\t\t{len(featured_topics)}\
        \naugmented_top228topics\t{len(augmented_top228topics)}\nmapped_topics\t\t{len(mapped_topics)}")

print()

print('Averages Number of Topics Per Repository')
print(f"original_topics\t\t{df['len_original_topics'].mean()}\nfeatured_topics\t\t{df['len_featured_topics'].mean()}\
        \naugmented_top228topics\t{df['len_augmented_top228topics'].mean()}\nmapped_topics\t\t{df['len_mapped_topics'].mean()}")
# Out:
# Topic Count
# original_topics		117865
# featured_topics		344
# augmented_top228topics	228
# mapped_topics		347
#
# Averages Number of Topics Per Repository
# original_topics		6.024346424655544
# featured_topics		1.5948361272936233
# augmented_top228topics	2.0719031955508
# mapped_topics		2.466862177835903

# %% [markdown]
# # Saving Prepped Data

# %%
to_drop = ['readme_raw']

df.drop(to_drop, axis=1, inplace=True)

df.original_topics = df.original_topics.apply(lambda x: ','.join(x))
df.featured_topics = df.featured_topics.apply(lambda x: ','.join(x))
df.augmented_top228topics = df.augmented_top228topics.apply(lambda x: ','.join(x))
df.mapped_topics = df.mapped_topics.apply(lambda x: ','.join(x))

df.to_csv('./2020_repologue_data/prepped_data.csv', index=None)

# %%
df = pd.read_csv('./2020_repologue_data/prepped_data.csv')

# %%
df
# Out:
#                                                 repo_name  \
# 0                                         ui-router/react
# 1                    novoda/gradle-android-command-plugin
# 2            aryarohit07/GlideFaceDetectionTransformation
# 3                                        tidyverse/modelr
# 4                                     robclancy/presenter
# ...                                                   ...
# 151393                                  brightec/KBarcode
# 151394                         icoxfog417/magenta_session
# 151395  a514514772/DISE-Domain-Invariant-Structure-Ext...
# 151396                                       nsqio/libnsq
# 151397                             peaceiris/actions-hugo
#
#                                           original_topics  \
# 0       javascript,react,router,spa,state-machine,type...
# 1             adb,gradle,gradle-plugin,novoda,open-source
# 2       android,detect-faces,face-detection,glide,visi...
# 3                                             modelling,r
# 4                         decorator,laravel,php,presenter
# ...                                                   ...
# 151393  android,android-barcode,android-development,ba...
# 151394                machine-learning,music,webaudio-api
# 151395  computer-vision,cvpr2019,deep-learning,domain-...
# 151396                               c,client-library,nsq
# 151397                        actions,github-actions,hugo
#
#                       featured_topics               augmented_top228topics  \
# 0         javascript,typescript,react  aurelia,javascript,typescript,react
# 1                  gradle,open-source                               gradle
# 2                             android                          api,android
# 3                                   r                                    r
# 4                         php,laravel                          php,laravel
# ...                               ...                                  ...
# 151393               firebase,android             firebase,android,library
# 151394               machine-learning                 machine-learning,api
# 151395  computer-vision,deep-learning        computer-vision,deep-learning
# 151396                              c                            library,c
# 151397                        actions                       actions,github
#
#                                     mapped_topics  len_original_topics  \
# 0       aurelia,javascript,react,typescript,unity                    7
# 1                      android,gradle,open-source                    5
# 2                              android,api,google                    5
# 3                                               r                    2
# 4                                     laravel,php                    4
# ...                                           ...                  ...
# 151393                   android,firebase,library                    7
# 151394                       api,machine-learning                    3
# 151395              computer-vision,deep-learning                    5
# 151396                           c,google,library                    3
# 151397                             actions,github                    3
#
#         len_featured_topics  len_augmented_top228topics  len_mapped_topics  \
# 0                         3                           4                  5
# 1                         2                           1                  3
# 2                         1                           2                  3
# 3                         1                           1                  1
# 4                         2                           2                  2
# ...                     ...                         ...                ...
# 151393                    2                           3                  3
# 151394                    1                           2                  2
# 151395                    2                           2                  2
# 151396                    1                           2                  3
# 151397                    1                           2                  2
#
#                               name_processed  \
# 0                            ui router react
# 1       novoda gradle android command plugin
# 2                       glide face detection
# 3                          tidyverse mode lr
# 4                                        NaN
# ...                                      ...
# 151393                               barcode
# 151394                       ico fog session
# 151395           domain structure extraction
# 151396                            io library
# 151397                      iris action hugo
#
#                                            desc_processed  \
# 0                                         ui router react
# 1                        handy command testing android ci
# 2       memory efficient android image transformation ...
# 3                               helper function modelling
# 4       decorate object using presenter primarily keep...
# ...                                                   ...
# 151393            library help implement barcode scanning
# 151394              musical keyboard music session google
# 151395  pytorch implementation structure structural in...
# 151396                  asynchronous c client library nsq
# 151397  github action hugo setup hugo quickly build si...
#
#                                          readme_processed  \
# 0       ui router react ui router provides extremely f...
# 1       gradle android command plugin build license bi...
# 2       glide face detection transformation download a...
# 3       badge start lifecycle stable travis build stat...
# 4       presenter decorate object using presenter prim...
# ...                                                   ...
# 151393  bintray library help implement barcode scannin...
# 151394  magenta session code session magenta midi inst...
# 151395  domain invariant structure extraction pytorch ...
# 151396  asynchronous c client library nsq status curre...
# 151397  license release github release date github act...
#
#                                            wiki_processed  \
# 0                                                     NaN
# 1       development development branch project make wa...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 151393  troubleshooting android support library versio...
# 151394                                                NaN
# 151395                                                NaN
# 151396                                                NaN
# 151397                                                NaN
#
#                                        filename_processed
# 0       deep transition stable nest hook ref child u r...
# 1       monkey dpland aware suffix valuessw android va...
# 2       detector value glide glide android transformat...
# 3       pipe toc problem resample geom r height data n...
# 4       password authenticated route pagination cooky ...
# ...                                                   ...
# 151393  calendar detekt pmd screen mockitoextensions c...
# 151394  target raw bundle sequence keyboard process to...
# 151395  cityscape psp label performance text python ne...
# 151396          upd c message http connection nsq look ut
# 151397                 github data o jest javascript brew
#
# [151398 rows x 14 columns]
